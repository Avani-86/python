# %%
app=["whatsapp","instagram","snapchat","youtube","chatgpt","pinterest","spotify"]
print(app)
print(app[5])
print(app[3:7])
# Out:
# ['whatsapp', 'instagram', 'snapchat', 'youtube', 'chatgpt', 'pinterest', 'spotify']
# pinterest
# ['youtube', 'chatgpt', 'pinterest', 'spotify']

# %%
str = "hello world"
print(str)
# Out:
# hello world

# %%
print(str[4])
print(str[8])
# Out:
# o
# r

# %%
#Strong concatenation

a = input("Enter a number")
b = input("enput a another number")
print(a+b)
# Out:
# 4567

# %%
#String Duplication

# %%
x = "Beautyful"
print(x)
# Out:
# Beautyful

# %%
x.upper()
# Out:
# 'BEAUTYFUL'

# %%
x.lower()
# Out:
# 'beautyful'

# %%
x.capitalize()
# Out:
# 'Beautyful'

# %%
y = "hello world"
y.title()
# Out:
# 'Hello World'

# %%
poem ='''Jonny Jonny yes papa
eating sugar no papa
telling a lie no papa
open your mouth haha'''
print(poem)
# Out:
# Jonny Jonny yes papa
# eating sugar no papa
# telling a lie no papa
# open your mouth haha

# %%
poem.find('papa')
# Out:
# 16

# %%
p = poem.replace('papa','bua').replace('sugar','rasmalai').replace('Jonny','awantika')
print(p)
# Out:
# awantika awantika yes bua
# eating rasmalai no bua
# telling a lie no bua
# open your mouth haha

# %%
a = "Sadhvi is fool"
a.split()
# Out:
# ['Sadhvi', 'is', 'fool']

# %%
poem.splitlines()
# Out:
# ['Jonny Jonny yes papa',
#  'eating sugar no papa',
#  'telling a lie no papa',
#  'open your mouth haha']

# %%
path = ('c:', 'user', 'desktop', 'Python')
print('/'.join(path))
# Out:
# c:/user/desktop/Python

# %%
text = "I learning Python"
words = text.split()
words.insert(1,"am")
new_text = " ".join(words)
print(new_text)
# Out:
# I am learning Python
