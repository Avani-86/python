# %%
import math

# %%
print(math.sqrt(16))
print(math.factorial(5))
print(math.gcd(10,20))
print(math.lcm(18,16))
print(math.log(100,10))
print(math.sin(90))
# Out:
# 4.0
# 120
# 10
# 144
# 2.0
# 0.8939966636005579

# %%
from random import random, randint, choice, shuffle

# %%
print("Get a number 0 and 1", random())
print("Get a random integer between 1 and 10:", randint(1, 10))
print("Get a random choice from a list:", choice(['apple','banana', 'cherry']))
names = ['Alice', 'Bob', 'Charlie', 'David']
shuffle(names)
print(names)
# Out:
# Get a number 0 and 1 0.675158312720567
# Get a random integer between 1 and 10: 8
# Get a random choice from a list: banana
# ['Bob', 'Charlie', 'Alice', 'David']

# %%
from datetime import datetime as dt #alias

# %%
print("Current Date and Time:", dt.now())
print("Current Date:", dt.now().date())
print("Current Time:", dt.now().time())
# Out:
# Current Date and Time: 2025-08-30 10:53:33.649740
# Current Date: 2025-08-30
# Current Time: 10:53:33.649927

# %%
print("Current Month:", dt.now().month)
print("Current Year:", dt.now().year)
print("Current Day:", dt.now().day)
print("Current Hour:", dt.now().hour)
# Out:
# Current Month: 8
# Current Year: 2025
# Current Day: 30
# Current Hour: 11

# %%
print("Current day name",dt.now().strftime("%a"))
print("Current time",dt.now().strftime(%H:%M:%S))
# Out:
#   Cell In[1], line 2
#     print("Current time",dt.now().strftime(%H:%M:%S))
#                                            ^
# SyntaxError: invalid syntax
