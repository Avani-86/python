# %%
student={
    "shaili":"99.9",
    "sadhvi":"45",
    "awantika":"98",
    "aadya":"65"
}
print(student)
# Out:
# {'shaili': '99.9', 'sadhvi': '45', 'awantika': '98', 'aadya': '65'}

# %%
How to declare dictionaries
How to access keys and values
How to apply loops
How to make nested dictionaries
How to access values in nested dictionaries

# %%
temp = {
    'Lko' :[35,40,37],
    'Delhi' :[30,32,34],
    'Mumbai' :[36,38,40]
}
print(temp)
# Out:
# {'Lko': [35, 40, 37], 'Delhi': [30, 32, 34], 'Mumbai': [36, 38, 40]}

# %%
info =dict(name= "awantika",age=input("Enter your age"),city="Lko")
print(info)
# Out:
# {'name': 'awantika', 'age': '45', 'city': 'Lko'}

# %%
#1st method to access value through key
print(student['awantika'])
info['city']
# Out:
# 98
# 'Lko'

# %%
#2nd method to access value through key
student.get('awantika')
temp.get("Lko")
# Out:
# [35, 40, 37]

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['shaili', 'sadhvi', 'awantika', 'aadya'])
# dict_values(['99.9', '45', '98', '65'])
# dict_items([('shaili', '99.9'), ('sadhvi', '45'), ('awantika', '98'), ('aadya', '65')])

# %%
for k,v in info.items():
    print(f'{k}:{v}')
# Out:
# name:awantika
# age:45
# city:Lko

# %%
company={
    'emp001':{
        'name':'Alice',
        'age':'25',
        'department':'HR'
    },
    'emp002':{
        'name':'vaibhav',
        'age':'21',
        'department':'IT'
    },
    'emp003':{
        'name':'awantika',
        'age':'21',
        'Department':'Finance'
    },
}
print(company)
# Out:
# {'emp001': {'name': 'Alice', 'age': '25', 'department': 'HR'}, 'emp002': {'name': 'vaibhav', 'age': '21', 'department': 'IT'}, 'emp003': {'name': 'awantika', 'age': '21', 'Department': 'Finance'}}

# %%
company['emp004']={
    'name':'Vaibhav ji',
    'age':'23',
    'department' : 'playboy'
}
print(company)
# Out:
# {'emp001': {'name': 'Alice', 'age': '25', 'department': 'HR'}, 'emo002': {'name': 'vaibhav', 'age': '21', 'department': 'IT'}, 'emp003': {'name': 'awantika', 'age': '21', 'Department': 'Finance'}, 'emp004': {'name': 'Vaibhav ji', 'age': '23', 'department': 'playboy'}}

# %%
company['emp002']['department']
# Out:
# 'IT'

# %%
#print the average temperature of lko key of temp dictionary
print(sum(temp['Lko'])/len(temp['Lko']))
# Out:
# 37.333333333333336
