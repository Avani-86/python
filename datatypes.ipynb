# %%
i = 50
i
type(i)
# Out:
# int

# %%
j = 4.5
type(j)
# Out:
# float

# %%
name = "nikki"
type(name)
number="345"
type(number)
print(type(number))
#print(name+number)
# Out:
# <class 'str'>

# %%
print("Net" + "flix")
# Out:
# Netflix

# %%
num = int(input("enter radius"))
num
area = 3.14*num*num

print("area of cirlce is :",area)
# Out:
# area of cirlce is : 3629.84

# %%
x = None
print(x)
# Out:
# None

# %%
#Special datatypes
#List

names = ["John","Herry","Robert"]
print(names[0])
names[0] = "Jack"
print(names)
# Out:
# John
# ['Jack', 'Herry', 'Robert']

# %%
#Tuples
coordinates = (56.9, 53.9)
print(coordinates)
coordinates[0] = 99.7
print(coordinates)
# Out:
# (56.9, 53.9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 coordinates = (56.9, 53.9)
#       3 print(coordinates)
# ----> 4 coordinates[1] = 99.7
#       5 print(coordinates)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Sets
num = {1,2,2,3,3,3,4,5}
fruits = {"apple","banana","cherry","apple"}
fruits.add("pineapple")
print(fruits)
# Out:
# {'pineapple', 'apple', 'cherry', 'banana'}

# %%
for i in fruits:
    print(i)
# Out:
# pineapple
# apple
# cherry
# banana

# %%
#Dictionaries
car_info = {
    "brand": "ford",
    "model": "mustang",
    "year":  1964
}
print(car_info)
print(car_info["model"])
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# mustang
